# %%
a <- read.csv("Rdata1/서울시_우리마을가게_상권분석서비스_2020년.csv",fileEncoding = "euc-kr")
head(a)
# Out:
#   기준_년_코드 기준_분기_코드 상권_구분_코드 상권_구분_코드_명 상권_코드
# 1 2020         1              A              골목상권          2110001
# 2 2020         1              A              골목상권          2110001
# 3 2020         1              A              골목상권          2110001
# 4 2020         1              A              골목상권          2110001
# 5 2020         1              A              골목상권          2110001
# 6 2020         1              A              골목상권          2110001
#   상권_코드_명 서비스_업종_코드 서비스_업종_코드_명 분기당_매출_금액
# 1 이북5도청사  CS100001         한식음식점          673117215
# 2 이북5도청사  CS100008         분식전문점           87592085
# 3 이북5도청사  CS100009         호프-간이주점        16496685
# 4 이북5도청사  CS100010         커피-음료            19442192
# 5 이북5도청사  CS200001         일반교습학원         21617575
# 6 이북5도청사  CS200016         당구장                9110595
#   분기당_매출_건수 ... 시간대_건수.24_매출_건수 남성_매출_건수 여성_매출_건수
# 1 26310            ... 561                      14980          8039
# ...

# %%
#subset((a,(서비스_업종_코드_명=="호프-간이주점"&상권_구분_코드_명=='관광특구')),기준_분기_코드) # 관광특구 내 호프-간이주점의 2021년 데이터셋[,-c(3,5,7,8,11:79)]

# %%
ncol(a)
unique(a$상권_구분_코드_명)
# Out:
# [1] 80
# [1] 골목상권 발달상권 전통시장 관광특구
# Levels: 골목상권 관광특구 발달상권 전통시장

# %%
class(b관)
# Out:
# [1] "data.frame"

# %%
b관 <- subset(a, (서비스_업종_코드_명=='호프-간이주점')&(상권_구분_코드_명 == '관광특구'))
b관[,-c(3,5,7,8,11:79)]
nrow(b관)
# Out:
#        기준_년_코드 기준_분기_코드 상권_구분_코드_명
# 36093  2020         1              관광특구
# 36139  2020         1              관광특구
# 36195  2020         1              관광특구
# 36241  2020         1              관광특구
# 36298  2020         1              관광특구
# 72509  2020         2              관광특구
# 72555  2020         2              관광특구
# 72610  2020         2              관광특구
# 72656  2020         2              관광특구
# 72713  2020         2              관광특구
# 108625 2020         3              관광특구
# 108671 2020         3              관광특구
# 108727 2020         3              관광특구
# 108773 2020         3              관광특구
# 108828 2020         3              관광특구
# 144479 2020         4              관광특구
# 144524 2020         4              관광특구
# 144580 2020         4              관광특구
# 144625 2020         4              관광특구
# 144681 2020         4              관광특구
#        상권_코드_명                            분기당_매출_금액
# 36093  이태원 관광특구                         5785496574
# ...

# %%
d2020 <- b관[ ,-c(3,5,7,8,11:79)]

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
arrange(d2020,상권_코드_명)
# Out:
#    기준_년_코드 기준_분기_코드 상권_구분_코드_명
# 1  2020         1              관광특구
# 2  2020         2              관광특구
# 3  2020         3              관광특구
# 4  2020         4              관광특구
# 5  2020         1              관광특구
# 6  2020         2              관광특구
# 7  2020         3              관광특구
# 8  2020         4              관광특구
# 9  2020         1              관광특구
# 10 2020         2              관광특구
# 11 2020         3              관광특구
# 12 2020         4              관광특구
# 13 2020         1              관광특구
# 14 2020         2              관광특구
# 15 2020         3              관광특구
# 16 2020         4              관광특구
# 17 2020         1              관광특구
# 18 2020         2              관광특구
# 19 2020         3              관광특구
# 20 2020         4              관광특구
#    상권_코드_명                            분기당_매출_금액 분기당_매출_건수
# 1  동대문패션타운 관광특구                 1299616917        34370
# 2  동대문패션타운 관광특구                 1486176768        47872
# ...

# %%
bb관 <- aggregate(cbind(분기당_매출_금액,점포수)~기준_분기_코드,b관, sum)
bb관
